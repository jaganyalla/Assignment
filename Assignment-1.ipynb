# %% [markdown]
# Task 1: Install Jupyter notebook and run the first program and share the screenshot of the output.

# %%
print("Hello Jagan")
# Out:
# Hello Jagan

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Task 2: Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
input_range = range(2000,3201)
output_list = []
for number in input_range:
    if (number%7==0 and number%5!=0):
        output_list.append(number)
print(*output_list,sep =',')
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %% [markdown]
# Task 2: output Screenshot
#     ![image.png](attachment:image.png)

# %% [markdown]
# Task 3: Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
first_name = input(" Please enter first name ")
last_name = input (" Please enter last name ")
print(last_name + " " + first_name)
# Out:
#  Please enter first name Jagan
#  Please enter last name Yalla
# Yalla Jagan

# %% [markdown]
# Task 3: Output
#     ![image.png](attachment:image.png)

# %% [markdown]
# Task 4: Write a Python program to find the volume of a sphere with diameter 12 cm.
#
# Formula: V=4/3 * π * r 3

# %%
import math
from units import unit
diameter = unit('cm')
radius = diameter(12) / 2
volume = 4/3 * math.pi * pow(radius,3)
print("Total Volume is " + str(volume))
# Out:
# Total Volume is 904.78 cm * cm * cm

# %% [markdown]
# Task 4: Output
#   ![image.png](attachment:image.png)

# %% [markdown]
# Task 5: Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
input_string = input("Enter a comma-separated numbers ")
output_list = []
for input_value in input_string.split(","):
  output_list.append(input_value)
print(output_list)
# Out:
# Enter a comma-separated numbers 10,20,30,40
# ['10', '20', '30', '40']

# %% [markdown]
# Task 5: Output
#   ![image.png](attachment:image.png)

# %% [markdown]
# Task 6: Create the below pattern using nested for loop in Python.
#
#
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(0,5):
  for j in range(0, i+1): 
    print("* ",end="")
  print("\r")  
for k in range(4,0,-1):
  for j in range(0, k): 
    print("* ",end="")
  print("\r")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# Task 6: Output
#    ![image.png](attachment:image.png)

# %% [markdown]
# Task 7: Write a Python program to reverse a word after accepting the input from the user.
#
# Sample Output:
#
# Input word: AcadGild
#
# Output: dilGdacA

# %%
input_string = input("Enter a input string")
print("reverse of string value is" , input_string[::-1])
# Out:
# Enter a input stringAcadGild
# reverse of string value is dliGdacA

# %% [markdown]
# Task 7: Output
#     ![image.png](attachment:image.png)

# %% [markdown]
# Task 8: Write a Python Program to print the given string in the format specified in the ​sample output.
#  WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens

# %%
print("WE, THE PEOPLE OF INDIA,\n\thaving solemnly resolved  to constitute India into a SOVEREIGN,!\n\t\tSOCIALIST, SECULAR, DEMOCRATIC REPUBLIC \n \t\t and to secure to all its citizens ")
# Out:
# WE, THE PEOPLE OF INDIA,
# 	having solemnly resolved  to constitute India into a SOVEREIGN,!
# 		SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#  		 and to secure to all its citizens

# %% [markdown]
# Task 8 : Output
#     ![image.png](attachment:image.png)
